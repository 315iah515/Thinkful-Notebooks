# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics
import math

# %matplotlib inline

# %% [markdown]
# The following binomial distribution is used as the population from which samples are created from for this drill on the Central Limit Theorem.

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.legend(loc='upper right') 
plt.show()

# %% [markdown]
# ## Expectations :
